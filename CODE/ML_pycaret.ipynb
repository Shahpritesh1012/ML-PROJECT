# %% [markdown]
# # 1.Introduction:
#
# • PyCaret is an open source, low-code machine learning library in Python that allows you to
# go from preparing your data to deploying your model within seconds in your choice of notebook environment.
#
# • PyCaret being a low-code library makes you more productive. With less time spent coding you and your team now focus on business problem.
#
# • PyCaret is simple and easy to use machine learning library that will help you to perform end-to-end ML experiments with less lines of code.
#
# • PyCaret is a business ready solution. It allows you to do prototyping quickly and efficiently from your choice of notebook environment.

# %% [markdown]
# # 2.Installing and importing libraries

# %%
#2.1 Installing PyCaret
# !pip install pycaret
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#2.2 Importing Libraries 
import pycaret
import numpy as np
import pandas as pd

# %%
#Check the version of the pycaret.
pycaret. __version__
# Out:
# '3.0.0'

# %% [markdown]
# # 3.Pycaret for Regression

# %% [markdown]
# # 3.1 Problem Statement
#
# • The dataset here consists of insurance data of different customers and their personal information.
#
# • You have to predict the insurance amount of an individual Also,analyse how diffrent features the  insurance amount of an individual.

# %%
# Table contents

Id Features   Description
01 Age        Age of the customer
02 Sex        Gender of the customer
03 Bmi        Body-Mass-Index of customer
04 Children   No.of children
05 Smoker     If the customer is a smoker or not
06 Region     Region of stay
07 Charges    Insurance Charge

total records:-1338

# %% [markdown]
# # 3.2 Reading the dataset

# %%
df_reg=pd.read_csv("insurance.csv")
df_reg
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # 3.3 Importing the modules

# %%
from pycaret.regression import *

# %% [markdown]
# # 3.4 Intitializing the module
#
# • PyCaret performs some basic preprocessing tasks,like ignoring the IDs and Date Columns,imputing the missing values,encoding the categorial variables,and splitting the dataset into the train-test split for the rest of the modeling steps.
#
# • When you run the setup function,it will first confirm the data types,and then if you press enter,it will create the environment for you to go ahead.

# %%
reg=setup(data=df_reg,train_size=0.8,target='charges',session_id=1362)
#By default here train size is 0.7(70%)
# Out:
# <style type="text/css">
# #T_3645d_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3645d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3645d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3645d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3645d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3645d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3645d_row0_col1" class="data row0 col1" >1362</td>
#     </tr>
#     <tr>
#       <th id="T_3645d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3645d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3645d_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_3645d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # 3.5 Compare the Models
#
# • This is another useful function of the PyCaret library.
#
# • If you do not want to try the diffrent models one by one,you can use the compare models function and it will train and compare common evalution metrics for all the available models in the library.

# %%
compare_models()
#or
#compare_models(include = ["gbr","lr","knn","rf","dt","br"])
# Out:
# <style type="text/css">
# #T_cccd5 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # 3.6 Creating The Model

# %%
gbr_model=create_model('gbr')
# Out:
# <style type="text/css">
# #T_bd994_row10_col0, #T_bd994_row10_col1, #T_bd994_row10_col2, #T_bd994_row10_col3, #T_bd994_row10_col4, #T_bd994_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bd994">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd994_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bd994_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bd994_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bd994_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bd994_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bd994_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# # 3.7 Tuning The Model

# %%
tunned_reg=tune_model(gbr_model)
# Out:
# <style type="text/css">
# #T_7f1a3_row10_col0, #T_7f1a3_row10_col1, #T_7f1a3_row10_col2, #T_7f1a3_row10_col3, #T_7f1a3_row10_col4, #T_7f1a3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7f1a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f1a3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7f1a3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7f1a3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7f1a3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7f1a3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7f1a3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# # 3.8 Predictions

# %%
predictions=predict_model(gbr_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9751d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9751d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9751d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9751d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9751d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9751d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9751d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9751d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9751d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9751d_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9751d_row0_col1" class="data row0 col1" >2528.2778</td>
# ...

# %% [markdown]
# # 3.9 Model Evalution

# %%
evaluate_model(gbr_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
